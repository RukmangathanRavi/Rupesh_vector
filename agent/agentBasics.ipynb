# %%
from pydantic import BaseModel

class LocalState(BaseModel):
        name : str = " "
        age: str =  " "
        message : str = " "

# %%
def Node(state:LocalState):
    state.message =  f"Hello {state.name} and your age is {state.age}"
    print(state)
    return state

# %%
from langgraph.graph import START, END, StateGraph

# From here only we have to start
builder = StateGraph(LocalState)
builder.add_node("node", Node)

builder.add_edge(START, "node")
builder.add_edge("node", END)

result = builder.compile()

result.invoke({"name":"Hello", "age":"21"})
# Out:
# name='Hello' age='21' message='Hello Hello and your age is 21'
# {'name': 'Hello', 'age': '21', 'message': 'Hello Hello and your age is 21'}

# %%
stateHello
# Out:
# State(name=' ', age=' ')
