# %%
from langchain_core.documents import Document


docs = Document(page_content="Hello I am the real data", metadata={"source":"../", "page":"2"})

docs
# Out:
# Document(metadata={'source': '../', 'page': '2'}, page_content='Hello I am the real data')

# %%
from langchain_community.document_loaders import TextLoader

doc = TextLoader(file_path="./file-sample.txt")

result = doc.load()

print(result[0].page_content)
# Out:
# Hello Rupesh just check with this as of now

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import WebBaseLoader, RecursiveUrlLoader

loader = WebBaseLoader(web_path="https://techsimplus.com/")

print(loader.load()[0].page_content)
# Out:
# TechSimPlus : Transforming Careers through Cutting-Edge Tech TrainingInternshipVector 1.OEventsAbout UsCertificateConnect UsLoginHomeEventsAbout UsInstitute SolutionConnect UsLoginJoin Vector 1.OCopyright 2026 © TechSimPlus - The Symbol of Expertise.Designed by  Prateek MishraCode. Build. Get Hired.Explore our courses12k+Trained Students200+Institute Trainings500+Projects11 LPA+Avarage CTCWatch intro videoOur students got a placementThese are students who joined Techsimplus to expand their careers and were placed on high-tech companies.Ashutosh MajhiAkshat JainAjay Kumar MandalAkash HarioudhAnuj PandeyAman ShahAnandita KumariAnkit LambaAnshu KumariAnuprash GuptaArun PariharBhagyashree GohiyaBharat TiwariManish Singh Naresh Choudhary Nidhi Khandelwal Nipun Gupta Pratiksha DubeyRaghav KabraVidhi bhardwajPrince KhatriTarun DangiTanay SisodiyaSee what our Student's SayDiscover what our students are saying about their transformative journey with us!Nipun GuptaLearning with TechSimPlus was
# ...

# %%
from bs4 import BeautifulSoup

def htmltotext(html:str) -> str:
    text = BeautifulSoup(html, "html.parser").get_text(" ")
    return text

from langchain_community.document_loaders import WebBaseLoader, RecursiveUrlLoader

loader = RecursiveUrlLoader(url="https://techsimplus.com/", max_depth=2, extractor=htmltotext)
loader.load()[0].page_content
# Out:
# "TechSimPlus : Transforming Careers through Cutting-Edge Tech Training Internship Vector 1.O Events About Us Certificate Connect Us Login Home Events About Us Institute Solution Connect Us Login Join Vector 1.O Copyright  2026  © TechSimPlus - The Symbol of Expertise. Designed by \xa0 Prateek Mishra Code. Build. Get Hired. Explore our courses 12 k+ Trained Students 200 + Institute Trainings 500 + Projects 11 LPA + Avarage CTC Watch intro video Our students got a placement These are students who joined Techsimplus to expand their careers and were placed on high-tech companies. Ashutosh Majhi Akshat Jain Ajay Kumar Mandal Akash Harioudh Anuj Pandey Aman Shah Anandita Kumari Ankit Lamba Anshu Kumari Anuprash Gupta Arun Parihar Bhagyashree Gohiya Bharat Tiwari Manish Singh  Naresh Choudhary  Nidhi Khandelwal  Nipun Gupta  Pratiksha Dubey Raghav Kabra Vidhi bhardwaj Prince Khatri Tarun Dangi Tanay Sisodiya See what our Student's Say Discover what our students are saying about their transf
# ...

# %%
pip install youtube-transcript-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import YoutubeLoader

loader = YoutubeLoader(video_id="w7j3SOkW0WE")

print(loader.load()[0].page_content)
# Out:
# One of my subscribers asked me, can you recommend 15 fragrances for life? And that got me really intrigued. 15 fragrances out of all the collections that I have over here. It will be difficult, but let's try. So with that idea in mind, I basically created a list of perfumes like 15 fragrances. If in case I'm never buying perfumes, these 15s will be the one that will keep me happy through and through. I know there are many that I will be missing out on, but I feel that out of that entire perfume collection that I have, these 15 will keep me happy no matter what. Also, I initially wanted to, you know, make the 15 perfume list as expensive as possible because, you know, I'm never going to buy perfumes again. But then I realized like I'm making this video with the Indian middle-class mindset in mind, right? So, I cannot go ahead and create a list of perfumes which are very very expensive and it doesn't make sense. Even I am not able to afford a lot of perfumes and I'm buying deans and te
# ...

# %%
pip install pymupdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyMuPDFLoader

doc = PyMuPDFLoader(file_path="./sample-local-pdf.pdf")

# print(doc.load()[0].page_content)

# print(doc.lazy_load())
for data in doc.lazy_load():
    print(data.page_content)
# Out:
# 1
# Sample PDF
#
# Created for testing PDFObject
#
# This PDF is three pages long. Three long pages. Or three short pages if
# you’re optimistic. Is it the same as saying “three long minutes”, knowing
# that all minutes are the same duration, and one cannot possibly be longer
# than the other? If these pages are all the same size, can one possibly be
# longer than the other?
#
# I digress. Here’s some Latin. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec
# odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum
# imperdiet. Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue semper porta. Mauris
# massa. Vestibulum lacinia arcu eget nulla. Class aptent taciti sociosqu ad litora torquent per
# conubia nostra, per inceptos himenaeos. Curabitur sodales ligula in libero.
#
# Sed dignissim lacinia nunc. Curabitur tortor. Pellentesque nibh. Aenean quam. In scelerisque sem
# ...
