# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

print(load_dotenv())
print(os.getenv("OPENAI_API_KEY"))

api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI()

stream = client.responses.create(
    model="gpt-5",
    input=[{
        "role":"system",
        "content":"You are a helpful Python tutor."
    },{
        'role':"user",
        'content':"Explain Python virtual environments in simple term"
    }
    ],
    max_output_tokens=1000,
    stream=True
)

for event in stream:
    if event.type == "response.output_text.delta":
        print(event.delta, end="", flush=True)

# print(response.output_text)
# print(response)
# print("Status:", response.status)
# print("Reason:", response.incomplete_details)
# print("Output:", response.output_text)
# Out:
# True
# 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
# Think of a Python virtual environment as a private toolbox for one project. It’s a folder that contains its own Python and packages, separate from everything else on your computer. That way, projects don’t fight over different package versions.
#
# Why use it
# - Keep each project’s packages and versions isolated
# - Reproduce installs easily on other machines
# - Avoid needing admin rights or breaking system Python
#
# How to use (simple steps)
# 1) Create one in your project folder
# - Run: python -m venv .venv
#   - This makes a folder named .venv with its own Python and pip
#
# 2) Activate it
# - Windows (PowerShell): .\.venv\Scripts\Activate.ps1
# - Windows (Cmd): .\.venv\Scripts\activate.bat
# - macOS/Linux: source .venv/bin/activate
# - Your shell prompt will show (.venv), meaning installs go into this env
#
# 3) Install packages
# - Example: pip install requests
#
# 4) Save what you installed (for sharing or rebuilding)
# - pip freeze > requirements.txt
# - Later (or on another machine): pip install -r requirements.txt
#
# 5) Stop using it
# - deactivate
#
# 6) Remove it
# - Just delete the .venv folder
#
# Tips
# - Use one virtual environment per project; name it .venv and add it to .gitignore
# - The Python version inside comes from the python you used to create it
# - VS Code and PyCharm can create/activate virtual environments for you
# - Alternatives that manage environments for you: Poetry, Pipenv, Conda (if you need data-science stacks or environment management beyond venv
